# %% [markdown]
# <a href="https://colab.research.google.com/github/BSA-projects/data-science-portfolio/blob/main/predictionmarkets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import modules
import json
import requests
import pandas as pd

# %%
endpoint = "https://api.elections.kalshi.com/trade-api/v2"

# %%
# Get series information
url = f'{endpoint}/{"markets?status=settled&limit=1000"}'
#stick with 100 for now and then check 500 later
print(url)
response = requests.get(url)
markets_data = response.json()
# Out:
# https://api.elections.kalshi.com/trade-api/v2/markets?status=settled&limit=1000

# %%
# Extract markets list
markets = markets_data.get("markets", [])

# Convert to DataFrame
df = pd.DataFrame(markets)
##display(df)

df = df[['title', 'last_price', 'volume', 'result']]

display(df)
# Out:
#                                                  title  last_price  volume  \
# 0    Will Mackenzie McDonald win the McDonald vs Ho...          99  133745
# 1    Will Brandon Holt win the McDonald vs Holt match?           1  109177
# 2    Will Yoshihito Nishioka win the Nishioka vs Ca...           1   19417
# 3    Will Pablo Carreno Busta win the Nishioka vs C...          99   44438
# 4    Will Arthur Rinderknech win the Medjedovic vs ...          44   22282
# ..                                                 ...         ...     ...
# 995        Ethereum price at Aug 17, 2025 at 12pm EDT?           0       0
# 996        Ethereum price at Aug 17, 2025 at 12pm EDT?           0       0
# 997        Ethereum price at Aug 17, 2025 at 12pm EDT?           0       0
# 998        Ethereum price at Aug 17, 2025 at 12pm EDT?           0       0
# 999        Ethereum price at Aug 17, 2025 at 12pm EDT?           0       0
#
#     result
# 0      yes
# 1       no
# 2       no
# 3      yes
# ...

# %%
# Extract markets with 0 trading vol
df_nonzero = df[df['volume'] > 0]

print(f"total markets with vol traded: {len(df_nonzero['title'])}")
# Out:
# total markets with vol traded: 134

# %%
# Calculate if public prediction was correct
def is_correct(row):
    predicted_yes = (row['last_price'] / 100) > 0.5
    actual_yes = row['result'].lower() == "yes"
    return predicted_yes == actual_yes

df_nonzero = df_nonzero.copy()
df_nonzero['correct'] = df_nonzero.apply(is_correct, axis=1)

display(df_nonzero)

# Overall accuracy
accuracy = df_nonzero['correct'].mean()

print(f"Public prediction accuracy: {accuracy:.2%}")

# Optional: see first few entries
print(df_nonzero.head())
# Out:
#                                                  title  last_price  volume  \
# 0    Will Mackenzie McDonald win the McDonald vs Ho...          99  133745
# 1    Will Brandon Holt win the McDonald vs Holt match?           1  109177
# 2    Will Yoshihito Nishioka win the Nishioka vs Ca...           1   19417
# 3    Will Pablo Carreno Busta win the Nishioka vs C...          99   44438
# 4    Will Arthur Rinderknech win the Medjedovic vs ...          44   22282
# ..                                                 ...         ...     ...
# 885         Ethereum price at Aug 17, 2025 at 1pm EDT?          98    2358
# 886         Ethereum price at Aug 17, 2025 at 1pm EDT?          76     100
# 957        Ethereum price at Aug 17, 2025 at 12pm EDT?           3     322
# 958        Ethereum price at Aug 17, 2025 at 12pm EDT?          97    1844
# 959        Ethereum price at Aug 17, 2025 at 12pm EDT?          94      13
#
#     result  correct
# 0      yes     True
# 1       no     True
# ...
